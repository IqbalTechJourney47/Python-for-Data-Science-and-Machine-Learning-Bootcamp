# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Lmplot (Linear Model Plot)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o', 'v'])

# %%
 sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o', 'v'], scatter_kws={'s':100})

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex', row='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', row='time', hue='sex')

# %%
# Seaborn figures can have the size and aspect ratio adjusted with size and aspect parameters.

sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex')

# %%
# Seaborn figures can have the size and aspect ratio adjusted with size and aspect parameters.

# aspect = ratio between the height and the width for esch of these seperate grids

sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', aspect=0.6)

# %%
# Seaborn figures can have the size and aspect ratio adjusted with size and aspect parameters.

# aspect = ratio between the height and the width for esch of these seperate grids

sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', aspect=0.6, size=8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       1 # Seaborn figures can have the size and aspect ratio adjusted with size and aspect parameters.
#       2
#       3 # aspect = ratio between the height and the width for esch of these seperate grids
# ----> 5 sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', aspect=0.6, size=8)
#
# TypeError: lmplot() got an unexpected keyword argument 'size'
