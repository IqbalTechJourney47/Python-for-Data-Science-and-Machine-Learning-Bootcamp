# %%
# For cleaning data
# For data preprocessing
import pandas as pd

# %%
# Read as a dataframe
df = pd.read_csv('water_potability.csv')

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
water_df = pd.read_csv('water_potability.csv')

# %%
water_df.head(100)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# ..       ...         ...           ...          ...         ...           ...
# 95  6.140878  197.876090  26687.874483     7.587196  329.231853    548.072761
# 96  7.077874  220.670540  23873.378210     6.181840  341.987234    333.050786
# 97  5.488314  135.802362  21485.153195     8.187416  280.603287    441.331137
# 98  7.205559  120.327615  24627.867560     6.202469  289.768697    418.433290
# 99  9.177870  163.274828  20868.331219     7.726040  320.421432    426.994393
#
# ...

# %%
import pandas as pd

# %%
fruits = ['apple', 'orange', 'banana', 'mango', 'cherry']
print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'mango', 'cherry']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
fruits_series = pd.Series(fruits)

# %%
fruits_series = pd.Series(fruits)
fruits_series
# Out:
# 0     apple
# 1    orange
# 2    banana
# 3     mango
# 4    cherry
# dtype: object

# %%
fruits_series = pd.Series(fruits)

# %%
fruits_series # 0, 1, 2, 3, 4 = Labels
# Out:
# 0     apple
# 1    orange
# 2    banana
# 3     mango
# 4    cherry
# dtype: object

# %%
# fruits_series = pd.Series(fruits, index = [10, 20, 30, 40, 50])

# %%
fruits_series # 0, 1, 2, 3, 4 = Labels
# Out:
# 0     apple
# 1    orange
# 2    banana
# 3     mango
# 4    cherry
# dtype: object

# %%
# Dictionary
student = {'Name': ['Ali', 'Amir', 'Ahmad', 'Ahad', 'Asad', 'Khuram'],
           'Age': [20, 30, 32, 21, 22, 65],
           'Marks': [345, 456, 670, 450, 900, 340],
           'Subject': ['OS', 'Database', 'OOP', 'Cyber security', 'SQA', 'IT']}

# %%
student
# Out:
# {'Name': ['Ali', 'Amir', 'Ahmad', 'Ahad', 'Asad', 'Khuram'],
#  'Age': [20, 30, 32, 21, 22, 65],
#  'Marks': [345, 456, 670, 450, 900, 340],
#  'Subject': ['OS', 'Database', 'OOP', 'Cyber security', 'SQA', 'IT']}

# %%
stu_df = pd.DataFrame(student)

# %%
stu_df.to_csv('student.csv')

# %%
pd.Series(student)
# Out:
# Name             [Ali, Amir, Ahmad, Ahad, Asad, Khuram]
# Age                            [20, 30, 32, 21, 22, 65]
# Marks                    [345, 456, 670, 450, 900, 340]
# Subject    [OS, Database, OOP, Cyber security, SQA, IT]
# dtype: object

# %%
# panda series can hold variety of object types

# passing a dictionary

df = pd.DataFrame (student)

# %%
# df = pd.DataFrame(student, index= [10, 20, 30, 40, 50, 60], columns = ['A', 'B', 'C', 'D', 'E', 'F'])

# %%
df
# Out:
#      Name  Age  Marks         Subject
# 0     Ali   20    345              OS
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
df.head()
# Out:
#     Name  Age  Marks         Subject
# 0    Ali   20    345              OS
# 1   Amir   30    456        Database
# 2  Ahmad   32    670             OOP
# 3   Ahad   21    450  Cyber security
# 4   Asad   22    900             SQA

# %%
# Displays records from last
df.tail()
# Out:
#      Name  Age  Marks         Subject
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
# Displays records from start
df.head(2)
# Out:
#    Name  Age  Marks   Subject
# 0   Ali   20    345        OS
# 1  Amir   30    456  Database

# %%
df.tail(3)
# Out:
#      Name  Age  Marks         Subject
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
# Display Random Records
df.sample(2)
# Out:
#    Name  Age  Marks         Subject
# 1  Amir   30    456        Database
# 3  Ahad   21    450  Cyber security

# %% [markdown]
# # Selection of data using iloc

# %%
stu_df.head(40)
# Out:
#      Name  Age  Marks         Subject
# 0     Ali   20    345              OS
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
stu_df.iloc[4]
# Out:
# Name       Asad
# Age          22
# Marks       900
# Subject     SQA
# Name: 4, dtype: object

# %%
stu_df.iloc[:4]
# Out:
#     Name  Age  Marks         Subject
# 0    Ali   20    345              OS
# 1   Amir   30    456        Database
# 2  Ahmad   32    670             OOP
# 3   Ahad   21    450  Cyber security

# %%
stu_df.iloc[4:6]
# Out:
#      Name  Age  Marks Subject
# 4    Asad   22    900     SQA
# 5  Khuram   65    340      IT

# %%
stu_df.loc[4]
# Out:
# Name       Asad
# Age          22
# Marks       900
# Subject     SQA
# Name: 4, dtype: object

# %%
stu_df
# Out:
#      Name  Age  Marks         Subject
# 0     Ali   20    345              OS
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
stu_df
# Out:
#      Name  Age  Marks         Subject
# 0     Ali   20    345              OS
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
stu_df.set_index('Name')
# Out:
#         Age  Marks         Subject
# Name
# Ali      20    345              OS
# Amir     30    456        Database
# Ahmad    32    670             OOP
# Ahad     21    450  Cyber security
# Asad     22    900             SQA
# Khuram   65    340              IT

# %%
stu_df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 stu_df2
#
# NameError: name 'stu_df2' is not defined

# %%
stu_df2 = stu_df.copy()

# %%
stu_df2
# Out:
#      Name  Age  Marks         Subject
# 0     Ali   20    345              OS
# 1    Amir   30    456        Database
# 2   Ahmad   32    670             OOP
# 3    Ahad   21    450  Cyber security
# 4    Asad   22    900             SQA
# 5  Khuram   65    340              IT

# %%
stu_df2.set_index('Name', inplace = True)

# %%
stu_df2
# Out:
#         Age  Marks         Subject
# Name
# Ali      20    345              OS
# Amir     30    456        Database
# Ahmad    32    670             OOP
# Ahad     21    450  Cyber security
# Asad     22    900             SQA
# Khuram   65    340              IT

# %%
stu_df.loc['Ali']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 stu_df.loc['Ali']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
stu_df.loc['Asad']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 stu_df.loc['Asad']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %% [markdown]
# # Lecture 12

# %%
stu_df2

# %%
stu_df['Marks']

# %%
stu_df2[['Marks', 'Subject']]

# %% [markdown]
# # Lecture 12

# %%
stu_df2[['Marks','Subject']]
# Out:
#         Marks         Subject
# Name
# Ali       345              OS
# Amir      456        Database
# Ahmad     670             OOP
# Ahad      450  Cyber security
# Asad      900             SQA
# Khuram    340              IT

# %%
stu_df2
# Out:
#         Age  Marks         Subject
# Name
# Ali      20    345              OS
# Amir     30    456        Database
# Ahmad    32    670             OOP
# Ahad     21    450  Cyber security
# Asad     22    900             SQA
# Khuram   65    340              IT

# %%
stu_df[stu_df['Name']=='Ahmad']
# Out:
#     Name  Age  Marks Subject
# 2  Ahmad   32    670     OOP

# %%
stu_df[stu_df['Name']=='Ahmad'][['Name','Marks','Subject']]
# Out:
#     Name  Marks Subject
# 2  Ahmad    670     OOP

# %%
stu_df[stu_df['Marks']>400][['Name','Marks','Subject']]
# Out:
#     Name  Marks         Subject
# 1   Amir    456        Database
# 2  Ahmad    670             OOP
# 3   Ahad    450  Cyber security
# 4   Asad    900             SQA

# %%
stu_df[stu_df['Marks']>=450][['Name','Marks','Subject']]
# Out:
#     Name  Marks         Subject
# 1   Amir    456        Database
# 2  Ahmad    670             OOP
# 3   Ahad    450  Cyber security
# 4   Asad    900             SQA

# %%
stu_df[stu_df['Marks']>=450]
# Out:
#     Name  Age  Marks         Subject
# 1   Amir   30    456        Database
# 2  Ahmad   32    670             OOP
# 3   Ahad   21    450  Cyber security
# 4   Asad   22    900             SQA

# %%
stu_df[(stu_df['Marks']>450)&(stu_df['Age']>20)]
# Out:
#     Name  Age  Marks   Subject
# 1   Amir   30    456  Database
# 2  Ahmad   32    670       OOP
# 4   Asad   22    900       SQA

# %%
stu_df[(stu_df['Marks']>450)|(stu_df['Age']>30)]
# Out:
#      Name  Age  Marks   Subject
# 1    Amir   30    456  Database
# 2   Ahmad   32    670       OOP
# 4    Asad   22    900       SQA
# 5  Khuram   65    340        IT

# %%
stu_df[~(stu_df['Age']>30)]
# Out:
#    Name  Age  Marks         Subject
# 0   Ali   20    345              OS
# 1  Amir   30    456        Database
# 3  Ahad   21    450  Cyber security
# 4  Asad   22    900             SQA

# %%
student = {'Name': ['Ali', 'Amir', 'Ahmad', 'Ahad', 'Ahmad', 'Khurram'],
          'Age': [20, 30, 32, 21, 22, 65],
          'Marks': [345, None, 670, 450, 900, None],
          'Subject': ['OS', 'Database', 'OOP', 'Cyber security', 'SQA', 'IT']}

# %%
stu_df = pd.DataFrame(student)

# %%
stu_df.drop(0)
# Out:
#       Name  Age  Marks         Subject
# 1     Amir   30    NaN        Database
# 2    Ahmad   32  670.0             OOP
# 3     Ahad   21  450.0  Cyber security
# 4    Ahmad   22  900.0             SQA
# 5  Khurram   65    NaN              IT

# %%
stu_df.set_index('Name', inplace=True)

# %%
stu_df.drop(['Ali'])
# Out:
#          Age  Marks         Subject
# Name
# Amir      30    NaN        Database
# Ahmad     32  670.0             OOP
# Ahad      21  450.0  Cyber security
# Ahmad     22  900.0             SQA
# Khurram   65    NaN              IT

# %%
stu_df.drop(['Ali','Ahmad'])
# Out:
#          Age  Marks         Subject
# Name
# Amir      30    NaN        Database
# Ahad      21  450.0  Cyber security
# Khurram   65    NaN              IT

# %%
stu_df.drop(['Age'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 stu_df.drop(['Age'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
stu_df.drop(['Age'],axis=1)

# %%
stu_df.drop(['Age','Subject'], axis=1)

# %%
stu_df.drop(['Age','Subject'], axis=1, inplace=True)

# %%
stu_df.drop('Ali')
# Out:
#          Marks
# Name
# Amir       NaN
# Ahmad    670.0
# Ahad     450.0
# Ahmad    900.0
# Khurram    NaN

# %%
new_data = stu_df2.drop('Ali')

# %%
new_data
# Out:
#         Age  Marks         Subject
# Name
# Amir     30    456        Database
# Ahmad    32    670             OOP
# Ahad     21    450  Cyber security
# Asad     22    900             SQA
# Khuram   65    340              IT

# %%
df = pd.read_csv('water_potability.csv')

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 1434

# %%
import seaborn as sns
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.to_csv('clean.csv')

# %%
df.sort_values('Organic_carbon').head(100)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 785   5.140801  209.358561  21407.614287     4.415976  230.555856
# 1390  7.593177  201.068737  19214.186357     7.710120  351.386080
# 2224  6.001382  186.884422  22554.830087     8.391883  331.214867
# 1447  5.122648  195.018888  17279.513749     7.027441  336.466042
# 876   8.020869  175.873676  21759.363929     7.487278  352.983112
# ...        ...         ...           ...          ...         ...
# 1482  7.015333  222.113004  16351.226287     7.838884  353.189806
# 1813  7.740454  182.541073  19713.504368     8.854386  382.341590
# 2029  7.560392  223.232250  14739.068540     6.731611  372.028909
# 2546  3.148712  142.272084  23257.208834     8.279275  293.160800
# 1932  7.185276  212.483172  25645.067233     8.142513  352.869165
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 785     378.897190        2.200000        86.737223   4.192257           1
# ...

# %%
df.sort_values('Organic_carbon', ascending=False)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2236  6.380717  266.015410  21250.935634     4.854335  357.241027
# 2057  5.690387  241.215729  14083.829888     5.738962  293.465164
# 43    9.920691  202.817483   9973.934059     6.882248  337.350529
# 3169  5.666446  142.147811  24383.741538     9.989551  320.264283
# 698   6.246264  163.218038  26408.881768     6.029670  429.022312
# ...        ...         ...           ...          ...         ...
# 876   8.020869  175.873676  21759.363929     7.487278  352.983112
# 1447  5.122648  195.018888  17279.513749     7.027441  336.466042
# 2224  6.001382  186.884422  22554.830087     8.391883  331.214867
# 1390  7.593177  201.068737  19214.186357     7.710120  351.386080
# 785   5.140801  209.358561  21407.614287     4.415976  230.555856
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2236    358.185473       27.006707        59.937785   4.532020           0
# ...

# %%
df.sort_values('Organic_carbon', ascending=False).head(100)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2236  6.380717  266.015410  21250.935634     4.854335  357.241027
# 2057  5.690387  241.215729  14083.829888     5.738962  293.465164
# 43    9.920691  202.817483   9973.934059     6.882248  337.350529
# 3169  5.666446  142.147811  24383.741538     9.989551  320.264283
# 698   6.246264  163.218038  26408.881768     6.029670  429.022312
# ...        ...         ...           ...          ...         ...
# 1426  7.042794  194.046719  16733.124103     7.701926  350.243966
# 1003  4.581969  186.097915  33897.068202     6.358402  316.552791
# 1774  6.950787  201.805491  21709.647709     6.120771  352.303771
# 1332  5.343075  211.662091  45166.912141     6.651801  279.767500
# 1166  5.716251  184.229295  19393.469862     5.299164  290.276455
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2236    358.185473       27.006707        59.937785   4.532020           0
# ...

# %%
df.sort_values('Organic_carbon')
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 785   5.140801  209.358561  21407.614287     4.415976  230.555856
# 1390  7.593177  201.068737  19214.186357     7.710120  351.386080
# 2224  6.001382  186.884422  22554.830087     8.391883  331.214867
# 1447  5.122648  195.018888  17279.513749     7.027441  336.466042
# 876   8.020869  175.873676  21759.363929     7.487278  352.983112
# ...        ...         ...           ...          ...         ...
# 698   6.246264  163.218038  26408.881768     6.029670  429.022312
# 3169  5.666446  142.147811  24383.741538     9.989551  320.264283
# 43    9.920691  202.817483   9973.934059     6.882248  337.350529
# 2057  5.690387  241.215729  14083.829888     5.738962  293.465164
# 2236  6.380717  266.015410  21250.935634     4.854335  357.241027
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 785     378.897190        2.200000        86.737223   4.192257           1
# ...

# %%
df['Organic_carbon'].apply(lambda x : x**2)
# Out:
# 3       339.905435
# 4       133.593824
# 5        70.555542
# 6       190.155697
# 7       152.863963
#            ...
# 3267     97.992486
# 3268    263.000915
# 3269    261.558019
# 3270    145.627442
# 3271    193.054866
# Name: Organic_carbon, Length: 2011, dtype: float64

# %%
def power(x):
    return x**2

# %%
df['Organic_carbon'].apply(lambda x : power(x))
# Out:
# 3       339.905435
# 4       133.593824
# 5        70.555542
# 6       190.155697
# 7       152.863963
#            ...
# 3267     97.992486
# 3268    263.000915
# 3269    261.558019
# 3270    145.627442
# 3271    193.054866
# Name: Organic_carbon, Length: 2011, dtype: float64
