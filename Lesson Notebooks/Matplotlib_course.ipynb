# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.show()

# %% [markdown]
# # Matplotlib Concepts

# %% [markdown]
# # Matplotlib course - Part 1

# %%
# Lets walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing
# numpy arrays or pandas columns (which essentially also behave like arrays).

# %% [markdown]
# # The data we want to plot:

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Functional method

plt.plot(x,y)

# %%
# Functional method

plt.plot(x,y)
plt.show()

# %%
'string'
# Out:
# 'string'

# %%
print('string')
# Out:
# string

# %%
# Functional method
# r = line color

plt.plot(x,y)
plt.plot(x,y, 'r-')

# %%
# Functional method

plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Multi-plots on the same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y, '-r')

plt.subplot(1,2,2)
plt.plot(y,x, 'b')

# %%
# Object-oriented method
fig = plt.figure()

# %%
# Object-oriented method
fig = plt.figure()

# fig.add_axes([left of the axes, bottom of the axes, height of the axes])

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# %%
# Object-oriented method
fig = plt.figure()

# fig.add_axes([left of the axes, bottom of the axes, width of the axes, height of the axes])

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x, y)

# %%
# Object-oriented method
fig = plt.figure()

# fig.add_axes([left of the axes, bottom of the axes, width of the axes, height of the axes])

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x, y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.15, 0.4, 0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.8, 0.5, 0.4, 0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.8, 0.15, 0.4, 0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.5, 0.15, 0.4, 0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# # Matplotlib course - Part2

# %%
fig,axes = plt.subplots()

# %%
fig,axes = plt.subplots()

axes.plot(x, y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

# %%
fig,axes = plt.subplots(nrows=3, ncols=3)

# %%
fig,axes = plt.subplots(nrows=3, ncols=3)

plt.tight_layout()

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')

plt.tight_layout()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %% [markdown]
# # Figure Size, Aspect Ratio and DPI

# %%
# figsize(width, height)
# dpi = dots per inch or pixels per inch

# fig = plt.figure(figsize=(3,2), dpi=100)

fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
# figsize(width, height)
# dpi = dots per inch or pixels per inch

# fig = plt.figure(figsize=(3,2), dpi=100)

fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig, axes = plt.subplots(figsize=(8,2))

axes.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
# Save a figure

fig

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# # Legends

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(y,x)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

ax.legend()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

# loc=0, best

ax.legend(loc=0)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

# loc=10, center

ax.legend(loc=10)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

ax.legend(loc=(0.1, 0.1))

# %% [markdown]
# # Matplotlib - Part 3
#
# # Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='blue')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='orange')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='green')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='#FF8C00') # RGB Hex Code

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple')

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=1)

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=2)

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=20)

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=0.5)

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=3)

# %%
# Line Width, Line Style

# alpha = transparency of the line

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth=3, alpha=0.5)

# %%
# Line Width, Line Style

# alpha = transparency of the line

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, alpha=0.5)

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='--')

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='-.')

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle=':')

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='steps')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 7
#       3 fig = plt.figure()
#       5 ax = fig.add_axes([0,0,1,1])
# ----> 7 ax.plot(x,y, color='purple', lw=3, linestyle='steps')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# ...

# %%
# Line Width, Line Style

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='-')

# %% [markdown]
# # Markers

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='-', marker='o')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=3, linestyle='-', marker='*')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=0.5, linestyle='-', marker='o', markersize=20)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=0.5, linestyle='-', marker='+', markersize=20)

# %% [markdown]
# # Marker face color
# # Marker edge width
# # Marker edge color

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=1, linestyle='-', marker='0', markersize=20,
       markerfacecolor='yellow')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:168, in check_shape(_shape, **kwargs)
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ...

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=1, linestyle='-', marker='0', markersize=20,
       markerfacecolor='yellow', markeredgewidth=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:168, in check_shape(_shape, **kwargs)
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ...

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=1, linestyle='-', marker='0', markersize=20,
       markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\matplotlib\markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File ~\anaconda3\lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:168, in check_shape(_shape, **kwargs)
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ...

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=2, ls='--')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=2, ls='--')

# Lower bound and upper bound

ax.set_xlim([0,1])
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', lw=2, ls='--')

# Lower bound and upper bound

ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)
